# %%
import pandas as pd

# %%
data={'CustID':[1,2,3],'Name':['Amit','Jyoti','Naresh']}

# %%
data
# Out:
# {'CustID': [1, 2, 3], 'Name': ['Amit', 'Jyoti', 'Naresh']}

# %%
data.keys()
# Out:
# dict_keys(['CustID', 'Name'])

# %%
data.values()
# Out:
# dict_values([[1, 2, 3], ['Amit', 'Jyoti', 'Naresh']])

# %%
data.items()
# Out:
# dict_items([('CustID', [1, 2, 3]), ('Name', ['Amit', 'Jyoti', 'Naresh'])])

# %%
type(data)
# Out:
# dict

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    CustID    Name
# 0       1    Amit
# 1       2   Jyoti
# 2       3  Naresh

# %% [markdown]
# # Extract any coloumn

# %%
df['Name']
# Out:
# 0      Amit
# 1     Jyoti
# 2    Naresh
# Name: Name, dtype: object

# %% [markdown]
# #Check condition

# %%
df[df['CustID']==2]
# Out:
#    CustID   Name
# 1       2  Jyoti

# %%
df2=df[df['CustID']==2]

# %%
df2
# Out:
#    CustID   Name
# 1       2  Jyoti

# %%
data={'CustID':[1,2,3,4,5,6,7],'Name':['Govind','Priya','Mukesh','Rahul',
                                       'Amit','Jyoti','Naresh']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    CustID    Name
# 0       1  Govind
# 1       2   Priya
# 2       3  Mukesh
# 3       4   Rahul
# 4       5    Amit
# 5       6   Jyoti
# 6       7  Naresh

# %% [markdown]
# # Show first 5 records

# %%
df.head()
# Out:
#    CustID    Name
# 0       1  Govind
# 1       2   Priya
# 2       3  Mukesh
# 3       4   Rahul
# 4       5    Amit

# %%
df.head(7)
# Out:
#    CustID    Name
# 0       1  Govind
# 1       2   Priya
# 2       3  Mukesh
# 3       4   Rahul
# 4       5    Amit
# 5       6   Jyoti
# 6       7  Naresh

# %% [markdown]
# # Show last 5 records

# %%
df.tail()
# Out:
#    CustID    Name
# 2       3  Mukesh
# 3       4   Rahul
# 4       5    Amit
# 5       6   Jyoti
# 6       7  Naresh

# %%
df.tail(3)
# Out:
#    CustID    Name
# 4       5    Amit
# 5       6   Jyoti
# 6       7  Naresh

# %% [markdown]
# # Show random records

# %%
df.sample()
# Out:
#    CustID    Name
# 6       7  Naresh

# %%
df.sample(3)
# Out:
#    CustID    Name
# 5       6   Jyoti
# 3       4   Rahul
# 0       1  Govind

# %% [markdown]
# # size

# %%
df.size
# Out:
# 14

# %% [markdown]
# #shape

# %%
df.shape
# Out:
# (7, 2)

# %% [markdown]
# # info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CustID  7 non-null      int64
#  1   Name    7 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 240.0+ bytes

# %% [markdown]
# # Statistic Details

# %%
df.describe()
# Out:
#          CustID
# count  7.000000
# mean   4.000000
# std    2.160247
# min    1.000000
# 25%    2.500000
# 50%    4.000000
# 75%    5.500000
# max    7.000000

# %% [markdown]
# # Arithmatic Sum

# %%
df['CustID'].sum()
# Out:
# 28

# %%
data={'CustID':[1,2,3,4,5,6,7],'Name':['Govind','Priya','Mukesh','Rahul',
                                       'Amit','Jyoti','Naresh'],'Gender':['Male','Female','Male','Female'
                                       ,'Male','Female','Male']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    CustID    Name  Gender
# 0       1  Govind    Male
# 1       2   Priya  Female
# 2       3  Mukesh    Male
# 3       4   Rahul  Female
# 4       5    Amit    Male
# 5       6   Jyoti  Female
# 6       7  Naresh    Male

# %%
df.groupby(['Gender']).sum()
# Out:
#         CustID                    Name
# Gender
# Female      12         PriyaRahulJyoti
# Male        16  GovindMukeshAmitNaresh

# %% [markdown]
# # Sort values

# %%
df.sort_values(by='CustID')
# Out:
#    CustID    Name  Gender
# 0       1  Govind    Male
# 1       2   Priya  Female
# 2       3  Mukesh    Male
# 3       4   Rahul  Female
# 4       5    Amit    Male
# 5       6   Jyoti  Female
# 6       7  Naresh    Male

# %%
df.sort_values(by='CustID', ascending=False)
# Out:
#    CustID    Name  Gender
# 6       7  Naresh    Male
# 5       6   Jyoti  Female
# 4       5    Amit    Male
# 3       4   Rahul  Female
# 2       3  Mukesh    Male
# 1       2   Priya  Female
# 0       1  Govind    Male

# %% [markdown]
# #Count unique values

# %%
df.value_counts()
# Out:
# CustID  Name    Gender
# 1       Govind  Male      1
# 2       Priya   Female    1
# 3       Mukesh  Male      1
# 4       Rahul   Female    1
# 5       Amit    Male      1
# 6       Jyoti   Female    1
# 7       Naresh  Male      1
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      4
# Female    3
# Name: count, dtype: int64

# %% [markdown]
# #Drop row-All colomns duplicated

# %%
df.drop_duplicates()
# Out:
#    CustID    Name  Gender
# 0       1  Govind    Male
# 1       2   Priya  Female
# 2       3  Mukesh    Male
# 3       4   Rahul  Female
# 4       5    Amit    Male
# 5       6   Jyoti  Female
# 6       7  Naresh    Male

# %%
df['Gender'].drop_duplicates()
# Out:
# 0      Male
# 1    Female
# Name: Gender, dtype: object

# %%
df
# Out:
#    CustID    Name  Gender
# 0       1  Govind    Male
# 1       2   Priya  Female
# 2       3  Mukesh    Male
# 3       4   Rahul  Female
# 4       5    Amit    Male
# 5       6   Jyoti  Female
# 6       7  Naresh    Male

# %%
df_male=df[df['Gender']=='Male']

# %%
df_male
# Out:
#    CustID    Name Gender
# 0       1  Govind   Male
# 2       3  Mukesh   Male
# 4       5    Amit   Male
# 6       7  Naresh   Male

# %% [markdown]
# #Add single coloumn

# %%
df
# Out:
#    CustID    Name  Gender
# 0       1  Govind    Male
# 1       2   Priya  Female
# 2       3  Mukesh    Male
# 3       4   Rahul  Female
# 4       5    Amit    Male
# 5       6   Jyoti  Female
# 6       7  Naresh    Male

# %%
df['Age']=[25,35,46,18,27,61,17]

# %%
df
# Out:
#    CustID    Name  Gender  Age
# 0       1  Govind    Male   25
# 1       2   Priya  Female   35
# 2       3  Mukesh    Male   46
# 3       4   Rahul  Female   18
# 4       5    Amit    Male   27
# 5       6   Jyoti  Female   61
# 6       7  Naresh    Male   17

# %%
df.drop(['CustID'],axis=1)
df
# Out:
#    CustID    Name  Gender  Age
# 0       1  Govind    Male   25
# 1       2   Priya  Female   35
# 2       3  Mukesh    Male   46
# 3       4   Rahul  Female   18
# 4       5    Amit    Male   27
# 5       6   Jyoti  Female   61
# 6       7  Naresh    Male   17

# %%
df.drop(['CustID'],axis=1,inplace=True)

# %%
df
# Out:
#      Name  Gender  Age
# 0  Govind    Male   25
# 1   Priya  Female   35
# 2  Mukesh    Male   46
# 3   Rahul  Female   18
# 4    Amit    Male   27
# 5   Jyoti  Female   61
# 6  Naresh    Male   17

# %%
# df.drop(['CustID', 'Age'],axis=1,inplace=True)

# %% [markdown]
# #Rename single column

# %%
df.rename(columns={'Name':'Customer Name'}, inplace=True)
df
# Out:
#   Customer Name  Gender  Age
# 0        Govind    Male   25
# 1         Priya  Female   35
# 2        Mukesh    Male   46
# 3         Rahul  Female   18
# 4          Amit    Male   27
# 5         Jyoti  Female   61
# 6        Naresh    Male   17

# %%
df.rename(columns={'Customer Name':'Customer_Name','Age':'CustAge'}, inplace=True)
df
# Out:
#   Customer_Name  Gender  CustAge
# 0        Govind    Male       25
# 1         Priya  Female       35
# 2        Mukesh    Male       46
# 3         Rahul  Female       18
# 4          Amit    Male       27
# 5         Jyoti  Female       61
# 6        Naresh    Male       17

# %% [markdown]
# #Update Single column single row

# %%
df.loc[df['CustAge']==17,'Customer_Name']=['Sachin']

# %%
df
# Out:
#   Customer_Name  Gender  CustAge
# 0        Govind    Male       25
# 1         Priya  Female       35
# 2        Mukesh    Male       46
# 3         Rahul  Female       18
# 4          Amit    Male       27
# 5         Jyoti  Female       61
# 6        Sachin    Male       17

# %%
df['CustAge']=99
df
# Out:
#   Customer_Name  Gender  CustAge
# 0        Govind    Male       99
# 1         Priya  Female       99
# 2        Mukesh    Male       99
# 3         Rahul  Female       99
# 4          Amit    Male       99
# 5         Jyoti  Female       99
# 6        Sachin    Male       99
