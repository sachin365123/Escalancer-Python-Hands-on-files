# %% [markdown]
# # Dictionary in Python

# %% [markdown]
# ![dict1.png](attachment:dict1.png)

# %% [markdown]
# ![dict2.jpg](attachment:dict2.jpg)

# %%
mario={'Player_name':['Savitha','Sarthak'],'Level':6,'Score': 547,'Coins':42,'Lives Remaining':3,'time Remaining':'2 Hrs'}
mario
# Out:
# {'Player_name': ['Savitha', 'Sarthak'],
#  'Level': 6,
#  'Score': 547,
#  'Coins': 42,
#  'Lives Remaining': 3,
#  'time Remaining': '2 Hrs'}

# %%
mario['Player_name']
# Out:
# ['Savitha', 'Sarthak']

# %%
mario['Player_name']='Sachin'
mario
# Out:
# {'Player_name': 'Sachin', 'Level': 6, 'Score': 547}

# %%
# Unique
mario={'Player_name':'Savitha','Level':6,'Score': 547,'Score':870,'Score':999}
mario
# Out:
# {'Player_name': 'Savitha', 'Level': 6, 'Score': 999}

# %%
# Unique
mario={'Player_name':'Savitha','Level':6,'Score': 547,'Score':870,'Score':999,'Player_name':'Kapil'}
mario
# Out:
# {'Player_name': 'Kapil', 'Level': 6, 'Score': 999}

# %% [markdown]
# ## keys

# %%
mario.keys()
# Out:
# dict_keys(['Player_name', 'Level', 'Score', 'Coins', 'Lives Remaining', 'time Remaining'])

# %% [markdown]
# ## values

# %%
mario.values()
# Out:
# dict_values([['Savitha', 'Sarthak'], 6, 547, 42, 3, '2 Hrs'])

# %% [markdown]
# ## items

# %%
mario.items()
# Out:
# dict_items([('Player_name', ['Savitha', 'Sarthak']), ('Level', 6), ('Score', 547), ('Coins', 42), ('Lives Remaining', 3), ('time Remaining', '2 Hrs')])

# %%
employee_detail={'emp_name':'rohan','city':'Ghaziabad','Age':65,'Contact No':8909603587}
employee_detail
type(employee_detail)
# Out:
# dict

# %%
# Exercise 1- Dictionaries
# Given the code below, use the correct code 
# on line 3 in order to return the value associated with key 4. 


crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

value = crypto[4]

print(value)
# Out:
# Stellar

# %%
# Exercise 2 - Dictionaries
# Given the code below, use the correct code on line 3 in 
# order to return the value associated with key 4. 

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

value = crypto.get(4)

print(value)
# Out:
# Stellar

# %%
# Exercise 3 - Dictionaries
# Given the code below, use the correct code on line 3 in 
# order to update the value associated with key 4 to "Cardano".

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

crypto[4]='Cardano'

print(crypto[4])
# Out:
# Cardano

# %%
# Exercise 4 - Dictionaries
# Given the code below, use the correct code on line
# 3 in order to add a new key-value pair to the dictionary: 6: "Monero"

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

crypto[6]='Monero'
crypto['Coin']='Indian INR'

print(crypto[6])
crypto.pop('Coin')
# Out:
# Monero
# 'Indian INR'

# %%
# Exercise 5 - Dictionaries
# Given the code below, use the correct code on line 3 
# in order to return the number of key-value pairs in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

number = len(crypto)

print(number)
# Out:
# 5

# %%
# Exercise 6 - Dictionaries
# Given the code below, use the correct code on line 3 
# in order to delete the key-value pair associated with key 3. 
# Do not use a method as a solution for this exercise!

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

del crypto

print(crypto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 10
#       6 crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}
#       8 del crypto
# ---> 10 print(crypto)
#
# NameError: name 'crypto' is not defined

# %%
# Exercise 7 - Dictionaries
# Given the code below, use the correct code on line 3 
# in order to delete the key-value pair associated with key 3. 
# This time, use a method as a solution for this exercise!



crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

crypto.pop(1)

print(crypto)
# Out:
# {2: 'Ethereum', 3: 'Litecoin', 4: 'Stellar', 5: 'XRP'}

# %%
# Exercise 8 - Dictionaries
# Given the code below, use the correct code on line 3 
# in order to verify that 7 is not a key in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

check = 5 in crypto

print(check)
# Out:
# True

# %%
# Exercise 9 - Dictionaries
# Given the code below, use the correct method on line 3 
# in order to delete all the elements in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

crypto.clear()

print(crypto)
# Out:
# {}

# %%
# Exercise 10 - Dictionaries
# Given the code below, use the correct code on
# line 3 in order to get a list of tuples, 
# where each tuple represents a key-value pair in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

result = crypto.items()
 
print(list(result))
# Out:
# [(1, 'Bitcoin'), (2, 'Ethereum'), (3, 'Litecoin'), (4, 'Stellar'), (5, 'XRP')]

# %%
# Exercise 11 - Dictionaries
# Given the code below, use the correct 
# function on line 3 in order to get the sum 
# of all the keys in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

add = sum(crypto)

print(add)
# Out:
# 15

# %%
# Exercise 12 - Dictionaries
# Given the code below, use the correct method on
# line 3 in order to get a list of all the values in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

val = crypto.values()

print(list(val))
# Out:
# ['Bitcoin', 'Ethereum', 'Litecoin', 'Stellar', 'XRP']

# %%
# Exercise 13 - Dictionaries
# Given the code below, use the correct function on 
# line 3 in order to get the smallest key in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

key = max(crypto)


for i in crypto.keys():
    if i>=key:
        


# print(key)

# %%
# Exercise 14 - Dictionaries
# Given the code below, use the correct method on 
# line 3 in order to get a list of all the keys in the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

keys = crypto.keys()

print(list(keys))
# Out:
# [1, 2, 3, 4, 5]

# %%
# Exercise 15 - Dictionaries
# Given the code below, use the correct method on 
# line 3 in order to return and remove an arbitrary 
# key-value pair from the dictionary.

crypto = {1: "Bitcoin", 2: "Ethereum", 3: "Litecoin", 4: "Stellar", 5: "XRP"}

crypto.popitem()

print(len(crypto))
# Out:
# 4
