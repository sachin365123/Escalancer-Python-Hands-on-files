# %%
# Machine Learning Algorithms

# %% [markdown]
# # Pandas Library in Python

# %%
import pandas as pd

# %%
data=pd.read_csv("car.csv")
# csv=comma sepearted values

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.head(12)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.tail(8)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# 295      Dealer       Manual      0
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# ...

# %%
data.sample(6)
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 26                       swift  2013           4.15           5.87
# 125  Royal Enfield Classic 500  2009           0.90           1.75
# 118  Royal Enfield Classic 350  2015           1.10           1.47
# 99                    fortuner  2010           9.65          20.45
# 263                       jazz  2016           6.60           7.70
# 185          Suzuki Access 125  2008           0.25           0.58
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 26        55138    Petrol      Dealer       Manual      0
# 125       40000    Petrol  Individual       Manual      0
# 118       26000    Petrol  Individual       Manual      0
# 99        50024    Diesel      Dealer       Manual      0
# 263       16002    Petrol      Dealer       Manual      0
# 185        1900    Petrol  Individual    Automatic      0

# %%
data.shape
# Out:
# (301, 9)

# %%
301*9
# Out:
# 2709

# %%
data.size
# Out:
# 2709

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data['Selling_Price']
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
data['Transmission']
# Out:
# 0      Manual
# 1      Manual
# 2      Manual
# 3      Manual
# 4      Manual
#         ...
# 296    Manual
# 297    Manual
# 298    Manual
# 299    Manual
# 300    Manual
# Name: Transmission, Length: 301, dtype: object

# %%
type(data['Selling_Price'])
# 1 D
# Out:
# pandas.core.series.Series

# %%
type(data)
# 2 D
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df2=data[['Selling_Price', 'Present_Price', 'Kms_Driven']]

# %%
df2.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven
# 0           3.35           5.59       27000
# 1           4.75           9.54       43000
# 2           7.25           9.85        6900
# 3           2.85           4.15        5200
# 4           4.60           6.87       42450

# %%
# copy partial dataset
df=data[['Owner','Kms_Driven','Fuel_Type']]

# %%
df.head()
# Out:
#    Owner  Kms_Driven Fuel_Type
# 0      0       27000    Petrol
# 1      0       43000    Diesel
# 2      0        6900    Petrol
# 3      0        5200    Petrol
# 4      0       42450    Diesel

# %% [markdown]
# ## analysis

# %%
data[data['Selling_Price']>20]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 51      fortuner  2015          23.00          30.61       40000    Diesel
# 63      fortuner  2015          23.50          35.96       47000    Diesel
# 64      fortuner  2017          33.00          36.23        6000    Diesel
# 82        innova  2017          23.00          25.39       15000    Diesel
# 86  land cruiser  2010          35.00          92.60       78000    Diesel
# 93      fortuner  2015          23.00          30.61       40000    Diesel
# 96        innova  2016          20.75          25.39       29000    Diesel
#
#    Seller_Type Transmission  Owner
# 51      Dealer    Automatic      0
# 63      Dealer    Automatic      0
# 64      Dealer    Automatic      0
# 82      Dealer    Automatic      0
# 86      Dealer       Manual      0
# 93      Dealer    Automatic      0
# 96      Dealer    Automatic      0

# %%
data[data['Selling_Price']<1]
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 37                         800  2003           0.35           2.28
# 124  Royal Enfield Classic 500  2012           0.95           1.75
# 125  Royal Enfield Classic 500  2009           0.90           1.75
# 126          Bajaj Avenger 220  2017           0.90           0.95
# 127          Bajaj Avenger 150  2016           0.75           0.80
# ..                         ...   ...            ...            ...
# 196                  Activa 3g  2008           0.17           0.52
# 197           Honda CB twister  2010           0.16           0.51
# 198         Bajaj Discover 125  2011           0.15           0.57
# 199             Honda CB Shine  2007           0.12           0.58
# 200           Bajaj Pulsar 150  2006           0.10           0.75
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 37       127000    Petrol  Individual       Manual      0
# ...

# %%
data[data['Seller_Type']=='Individual']
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 27                swift  2017           6.00           6.49       16200
# 37                  800  2003           0.35           2.28      127000
# 53             fortuner  2013          16.00          30.61      135000
# 54               innova  2005           2.75          10.21       90000
# 85                camry  2006           2.50          23.73      142000
# ..                  ...   ...            ...            ...         ...
# 196           Activa 3g  2008           0.17           0.52      500000
# 197    Honda CB twister  2010           0.16           0.51       33000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
# 199      Honda CB Shine  2007           0.12           0.58       53000
# 200    Bajaj Pulsar 150  2006           0.10           0.75       92233
#
#     Fuel_Type Seller_Type Transmission  Owner
# 27     Petrol  Individual       Manual      0
# ...

# %%
data[data['Car_Name']=='Honda CB Shine']
# Out:
#            Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 182  Honda CB Shine  2013           0.30           0.58       30000    Petrol
# 199  Honda CB Shine  2007           0.12           0.58       53000    Petrol
#
#     Seller_Type Transmission  Owner
# 182  Individual       Manual      0
# 199  Individual       Manual      0

# %%
data[data['Car_Name']=='Bajaj Discover 125']
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 191  Bajaj Discover 125  2012           0.20           0.57       25000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 191    Petrol  Individual       Manual      1
# 198    Petrol  Individual       Manual      1

# %%
#Sort the data: km_driven based
data.sort_values(by='Kms_Driven')
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 133  Bajaj Avenger 220  2016           0.72           0.95         500
# 165          Activa 3g  2016           0.45           0.54         500
# 166   Hero Passion Pro  2016           0.45           0.55        1000
# 103  Bajaj Dominar 400  2017           1.45           1.60        1200
# 126  Bajaj Avenger 220  2017           0.90           0.95        1300
# ..                 ...   ...            ...            ...         ...
# 77             corolla  2004           1.50          12.35      135154
# 85               camry  2006           2.50          23.73      142000
# 84              innova  2005           3.49          13.46      197176
# 179      Honda Karizma  2010           0.31           1.05      213000
# 196          Activa 3g  2008           0.17           0.52      500000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 133    Petrol  Individual       Manual      0
# ...

# %%
#Sort the data: km_driven based
data.sort_values(by='Selling_Price')
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 200    Bajaj Pulsar 150  2006           0.10           0.75       92233
# 199      Honda CB Shine  2007           0.12           0.58       53000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
# 197    Honda CB twister  2010           0.16           0.51       33000
# 196           Activa 3g  2008           0.17           0.52      500000
# ..                  ...   ...            ...            ...         ...
# 82               innova  2017          23.00          25.39       15000
# 93             fortuner  2015          23.00          30.61       40000
# 63             fortuner  2015          23.50          35.96       47000
# 64             fortuner  2017          33.00          36.23        6000
# 86         land cruiser  2010          35.00          92.60       78000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 200    Petrol  Individual       Manual      0
# ...

# %%
#Sort the data: km_driven based
data.sort_values(by='Selling_Price', ascending=False)
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 86         land cruiser  2010          35.00          92.60       78000
# 64             fortuner  2017          33.00          36.23        6000
# 63             fortuner  2015          23.50          35.96       47000
# 82               innova  2017          23.00          25.39       15000
# 51             fortuner  2015          23.00          30.61       40000
# ..                  ...   ...            ...            ...         ...
# 196           Activa 3g  2008           0.17           0.52      500000
# 197    Honda CB twister  2010           0.16           0.51       33000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
# 199      Honda CB Shine  2007           0.12           0.58       53000
# 200    Bajaj Pulsar 150  2006           0.10           0.75       92233
#
#     Fuel_Type Seller_Type Transmission  Owner
# 86     Diesel      Dealer       Manual      0
# ...

# %%
df3=data.groupby('Car_Name')

# %%
df3.head()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 273     jazz  2010           2.25           7.50       61203    Petrol
# 274     brio  2014           5.30           6.80       16500    Petrol
# 278     jazz  2016           6.00           8.40        4000    Petrol
# 285     jazz  2016           7.40           8.50       15059    Petrol
# 287    amaze  2015           5.75           7.50       44000    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data['Car_Name'].value_counts()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
data['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
195+106
# Out:
# 301

# %% [markdown]
# # Apply function

# %%
def sarthak_name(name):
    return name[::-1]

# %%
def sachin(var):
    return var*20

# %%
name='Machine Learning'
name[::-1]
# Out:
# 'gninraeL enihcaM'

# %%
data['Transmission']=data['Transmission'].apply(sarthak_name)

# %%
data['Selling_Price']=data['Selling_Price'].apply(sachin)

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       launaM      0
# 1        Dealer       launaM      0
# ...

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           67.0           5.59       27000    Petrol
# 1        sx4  2013           95.0           9.54       43000    Diesel
# 2       ciaz  2017          145.0           9.85        6900    Petrol
# 3    wagon r  2011           57.0           4.15        5200    Petrol
# 4      swift  2014           92.0           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016          190.0          11.60       33988    Diesel
# 297     brio  2015           80.0           5.90       60000    Petrol
# 298     city  2009           67.0          11.00       87934    Petrol
# 299     city  2017          230.0          12.50        9000    Diesel
# 300     brio  2016          106.0           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       launaM      0
# 1        Dealer       launaM      0
# ...

# %%
3.35*20
# Out:
# 67.0

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           67.0           5.59       27000    Petrol
# 1        sx4  2013           95.0           9.54       43000    Diesel
# 2       ciaz  2017          145.0           9.85        6900    Petrol
# 3    wagon r  2011           57.0           4.15        5200    Petrol
# 4      swift  2014           92.0           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016          190.0          11.60       33988    Diesel
# 297     brio  2015           80.0           5.90       60000    Petrol
# 298     city  2009           67.0          11.00       87934    Petrol
# 299     city  2017          230.0          12.50        9000    Diesel
# 300     brio  2016          106.0           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       launaM      0
# 1        Dealer       launaM      0
# ...

# %%
data.to_csv('nitesh.csv')

# %%
data.to_excel('kapil.xlsx',sheet_name='Sheet1')
